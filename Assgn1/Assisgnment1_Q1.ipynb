# %%
import pandas as pd
df=pd.read_csv("automobiles.csv",names=["symboling", "normalized-losses", "make", "fuel-type", "aspiration", "num-of-doors", "body-style", "drive-wheels", "engine-location", "wheel-base", "length", "width", "height", "curb-weight", "engine-type", "num-of-cylinders", "engine-size", "fuel-system", "bore", "stroke", "compression-ratio", "horsepower", "peak-rpm", "city-mpg", "highway-mpg", "price"])

df.head(205)

df.replace("?","",inplace=True)
df.to_csv("automobiles3.csv",index=False)
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                    alfa-romero       gas        std
# 1            3                    alfa-romero       gas        std
# 2            1                    alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df=pd.read_csv("automobiles3.csv")
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         164.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          35.442168    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          94.000000   94.500000  166.300000   64.100000
# 50%      1.000000         115.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  201.000000  201.000000
# mean    53.724878  2555.565854   126.907317    3.329751    3.255423
# std      2.443522   520.680204    41.642693    0.273539    0.316717
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.dropna(axis=0,how="all",inplace=True)      #first drop those rows which have all 0s..

# %%
df.shape      #no rows deleted
# Out:
# (205, 26)

# %%
df.dropna(axis=0,how="any",inplace=False)
# Out:
#      symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 3            2              164.0   audi       gas        std         four
# 4            2              164.0   audi       gas        std         four
# 6            1              158.0   audi       gas        std         four
# 8            1              158.0   audi       gas      turbo         four
# 10           2              192.0    bmw       gas        std          two
# ..         ...                ...    ...       ...        ...          ...
# 200         -1               95.0  volvo       gas        std         four
# 201         -1               95.0  volvo       gas      turbo         four
# 202         -1               95.0  volvo       gas        std         four
# 203         -1               95.0  volvo    diesel      turbo         four
# 204         -1               95.0  volvo       gas      turbo         four
#
# ...

# %%
df.shape            #too many rows deleted...lot of information lost
# Out:
# (205, 26)

# %%
df=pd.read_csv("automobiles3.csv")     #read again csv file

# %%
df.shape
# Out:
# (205, 26)

# %%
df.dropna(axis=0,thresh=24,inplace=True)    #remove rows having "more than" 26-24=2 NaN values

# %% [markdown]
# # Handling Nan  values

# %% [markdown]
# ### normalized-losses column

# %%
df.boxplot(column=["normalized-losses"],color="red")
# Out:
# <AxesSubplot:>

# %%
df["normalized-losses"].describe()   #mean(122.0) is skewed towards right of median(115.0)
# Out:
# count    164.000000
# mean     122.000000
# std       35.442168
# min       65.000000
# 25%       94.000000
# 50%      115.000000
# 75%      150.000000
# max      256.000000
# Name: normalized-losses, dtype: float64

# %%
import matplotlib.pyplot as pt
pt.hist(df["normalized-losses"])
# Out:
# (array([17., 46., 31., 20., 21., 18.,  9.,  0.,  1.,  1.]),
#  array([ 65. ,  84.1, 103.2, 122.3, 141.4, 160.5, 179.6, 198.7, 217.8,
#         236.9, 256. ]),
#  <BarContainer object of 10 artists>)

# %%
df["normalized-losses"].fillna(df["normalized-losses"].median(),inplace=True)  #replace Nan values with median because

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              115.0  alfa-romero       gas        std
# 1            3              115.0  alfa-romero       gas        std
# 2            1              115.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
#pwd

# %%
#cd /home/ayush/Desktop/"python notebooks"/datasets

# %% [markdown]
# ### num-of-doors column

# %%
df["num-of-doors"].value_counts()      #four occurs more frequently. So we will fill four in Nan
# Out:
# four    113
# two      88
# Name: num-of-doors, dtype: int64

# %%
#all Dodge-sedans as well as mazda-sedans have four doors, so we fill Nan field of them as four
df["num-of-doors"].fillna("four",inplace=True)

# %% [markdown]
# ### bore column

# %%
df["bore"].describe()       #mean and median are aligned
# Out:
# count    199.000000
# mean       3.328442
# std        0.274602
# min        2.540000
# 25%        3.150000
# 50%        3.310000
# 75%        3.590000
# max        3.940000
# Name: bore, dtype: float64

# %%
pt.hist(df["bore"])
# Out:
# (array([ 1.,  1.,  8., 37., 40., 24., 25., 42., 17.,  4.]),
#  array([2.54, 2.68, 2.82, 2.96, 3.1 , 3.24, 3.38, 3.52, 3.66, 3.8 , 3.94]),
#  <BarContainer object of 10 artists>)

# %%
#all Dodge sedans as well as mazda sedans have four doors, so we fill Nan field of them as four

df["bore"].fillna(df["bore"].mean(),inplace=True)

# %% [markdown]
# ### stroke column

# %%
df["stroke"].describe()
# Out:
# count    199.000000
# mean       3.248945
# std        0.311583
# min        2.070000
# 25%        3.110000
# 50%        3.290000
# 75%        3.410000
# max        4.170000
# Name: stroke, dtype: float64

# %%
df["stroke"].fillna(df["stroke"].mean(),inplace=True)

# %% [markdown]
# ### horsepower column

# %%
df["horsepower"].fillna(df["horsepower"].median(),inplace=True)

# %% [markdown]
# ### peak-rpm column

# %%
df["peak-rpm"].value_counts()
# Out:
# 5500.0    37
# 4800.0    36
# 5000.0    27
# 5200.0    23
# 5400.0    13
# 6000.0     9
# 5250.0     7
# 4500.0     7
# 5800.0     7
# 4150.0     5
# 4200.0     5
# 4350.0     4
# 4750.0     4
# 4400.0     3
# 5900.0     3
# 4250.0     3
# 5100.0     3
# 6600.0     2
# 5750.0     1
# 4900.0     1
# 4650.0     1
# 5300.0     1
# 5600.0     1
# Name: peak-rpm, dtype: int64

# %%
df["peak-rpm"].fillna(df["peak-rpm"].mean(),inplace=True)

# %%
df.isnull().sum()            #now all features have non null values
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df.drop(["price"],axis=1,inplace=True)

# %%
df.to_csv("automobiles_refined_features.csv")

# %%
#dropping non numeric columns for KNN distance calculations
df = df.select_dtypes(exclude=['object'])

# %%
df.dtypes         #now all columns/features are numeric type
# Out:
# symboling              int64
# normalized-losses    float64
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-size            int64
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# dtype: object

# %% [markdown]
# # Scaling of each column in range [0,1] so that every column is given same prefernce

# %%
df=(df-df.min())/(df.max()-df.min())

# %%
#df.drop(["symboling"],axis=1)     #Drop column symboling because it takes only discrete values and other columns are continuous

# %% [markdown]
# # Training and Testing

# %%
df2=pd.read_csv("automobiles3.csv")
df["price"]=df2["price"]       #re-adding price column after normalization of dataframe
df["price"].fillna(df["price"].median(),inplace=True)   #Handling NaN values in price column
df3=df.drop(["normalized-losses","highway-mpg","city-mpg"],axis=1)      #i am removing whole normalized-losses column because 41 its 41 entries are null i.e. nearly 20% entrie are null. This is giving better accuracy. Also I have removed two other columns based on their correlation value with price
training_data=df3.sample(frac=0.67)
test_data= df3.drop(training_data.index)

# %%
import math
def manhattan_distance(row1, row2):
    distance = 0.0
    for i in range(len(row1)-1):
        distance += abs(row1[i] - row2[i])
    return distance

# %%
k=3        #k=5 was giving rmse in range 1000-3000  
for i in range(len(test_data)):
    rmse=0.0
    d_list=list()
    for j in range(len(training_data)):
        d_list.append((manhattan_distance(test_data.iloc[i],training_data.iloc[j]),training_data.iloc[j]["price"]))
    d_list.sort()
    sum=0.0
    for i in range(k):
        sum+=d_list[i][1]
    sum=sum/k    
    rmse+=(sum-test_data.iloc[i]["price"])**2
rmse=rmse/(len(test_data))    
rmse=math.sqrt(rmse)

# %%
print(rmse)   #this is the result of model on the test_data split from the initial training data. I am assuming that
              #the initial data taken from uci is training data. I have split this into two parts. So the data
              #which I have used here for testing is nothing but validation set data. One may also assume 3 splits
              #of the initial data into training ,validation and test sets( this I have not done here)
# Out:
# 38.07614349104861

# %% [markdown]
# # Cross validation for hyperparameter tuning

# %% [markdown]
# ### Now I will split the 136 rows(67% of initial rows) furthur into a new validation set

# %%
#I am applying holdout cross validation method within the training data set(of 136 rows). I will keep aside 33%
#of this training data set to be used as validation set.
training_data2=training_data.sample(frac=0.67)
validation_data=training_data.drop(training_data2.index)

# %%
import math

x_axis=list()     #for plotting
y_axis=list()     #for plotting
k=1
while(k<16):
    for i in range(len(validation_data)):   #iterating over validation set rows
        rmse=0.0
        d_list=list()                       # a list for storing distance of ith validation row with every training row
        for j in range(len(training_data2)):    #iterating over training set rows
            d_list.append((manhattan_distance(validation_data.iloc[i],training_data2.iloc[j]),training_data2.iloc[j]["price"]))
        d_list.sort()
        sum=0.0
        for i in range(k):
            sum+=d_list[i][1]
        sum=sum/k    
        rmse+=(sum-validation_data.iloc[i]["price"])**2
        rmse=rmse/(len(validation_data))    
        rmse=math.sqrt(rmse)
    x_axis.append(k)
    y_axis.append(rmse)
    k=k+2

# %%
import matplotlib.pyplot as plot    # a plot showing value of rmse for k=1,3,5,7,9,11,13,15
fig=plot.figure()
ax=fig.add_axes([0,0,1,1])
ax.bar(x_axis,y_axis)
plot.title("K vs RMSE")
plot.xlabel("K")
plot.ylabel("RMSE")
plot.show()

# %% [markdown]
# # Important features identified by our model for predicting prices

# %%
corr_df=df.corr()    # correlation dataframe shows that city-mpg and highway-mpg are poorly related to price
corr_df              # Also, engine-size, curb-weight and compression-ratio are top 3 highly correlated to price
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.459281   -0.533621 -0.358188
# normalized-losses   0.459281           1.000000   -0.074561 -0.006123
# wheel-base         -0.533621          -0.074561    1.000000  0.878139
# length             -0.358188          -0.006123    0.878139  1.000000
# width              -0.234364           0.058935    0.797576  0.841173
# height             -0.537520          -0.368263    0.591503  0.493761
# curb-weight        -0.227460           0.064237    0.776901  0.878776
# engine-size        -0.106305           0.072766    0.570455  0.683610
# bore               -0.131460          -0.048421    0.491953  0.605846
# stroke             -0.012406           0.048998    0.173998  0.124019
# compression-ratio  -0.178734          -0.115498    0.248601  0.160169
# horsepower          0.071622           0.166629    0.352297  0.555003
# ...

# %% [markdown]
# ### The top 5 features which are highly determining the price of car are:-
# ### 1)engine-size
# ### 2)curb-weight
# ### 3)compression-ratio
# ### 4)width
# ### 5)length
#
# ### In the real world, size of engine undoubtedly decides the price of car. More powerful the engine, the more costly car becomes and vice versa. Curb weight is the weight of car. I cannot think any other reason for why it can determine the price except for the fact that in general, bigger cars have more features and are costlier. Simlarly, compression ratio, width and length also highly determine the price of car

# %%
import pandas as pd
df=pd.read_csv("adult_data.csv")
df
# Out:
#        Unnamed: 0  age          workclass  fnlwgt    education  education-num  \
# 0               0   39          State-gov   77516    Bachelors             13
# 1               1   50   Self-emp-not-inc   83311    Bachelors             13
# 2               2   38            Private  215646      HS-grad              9
# 3               3   53            Private  234721         11th              7
# 4               4   28            Private  338409    Bachelors             13
# ...           ...  ...                ...     ...          ...            ...
# 32556       32556   27            Private  257302   Assoc-acdm             12
# 32557       32557   40            Private  154374      HS-grad              9
# 32558       32558   58            Private  151910      HS-grad              9
# 32559       32559   22            Private  201490      HS-grad              9
# 32560       32560   52       Self-emp-inc  287927      HS-grad              9
#
# ...

# %% [markdown]
# # Data preprocessing

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     597
# salary               0
# dtype: int64

# %% [markdown]
# # Decision Tree

# %%
#check for leaf node
def is_leaf(samples=None):
    unique_labels=np.unique(samples)
    if unique_labels==1:
        return True
    return False



#find entropy
def entropy(self, elements):
        total_labels = np.unique(elements)
        entropy = 0.0
        for labels in total_labels:
            iterm = len(elements[elements == labels]) / len(elements)
            entropy += -iterm * np.log2(iterm)
        return entropy
    

class Node:
    def __init__(self,value=None,left=None,right=None,thresh=None,is_leaf=None):
        self.value=value
        if not is_leaf:
            self.left=left
            self.right=right
            self.thresh=thresh
        
class DecisionTree:
    def __init__(self,min_samples=10,max_depth=100):
        self.min_samples=min_samples
        self.max_depth=max_depth
    
    
    def fit(self, dataset, curr_depth=0):
        features=dataset.drop(["salary"],axis=1)
        target=dataset["salary"]
        samples_n=len(dataset)
        features_n=len(dataset)
        if samples_n>=self.min_samples_split and curr_depth<=self.max_depth:
            best_split = self.get_best_split(dataset, samples_n, features_n)
            if best_split["IG"]>0:     #IG=0 means node was homogeneous
                lst = self.fit(best_split["dataset_left"], curr_depth+1)
                rst = self.fit(best_split["dataset_right"], curr_depth+1)
                return Node(best_split["index_of_feature"], best_split["thresh"], 
                            lst, rst, best_split["IG"])
        
        value = self.get_value(features)
        
        
        return Node(value=leaf_value)
